# %%
import numpy as np
import pandas as pd
import re

# %%
raw_data = pd.read_csv("../data/raw/diabetic_data.csv", keep_default_na=False, na_values=["?"], low_memory=False)

# %% [markdown]
# ### Drop columns that exceed the 20% acceptable threshold for missing values

# %%
raw_data = raw_data.drop(columns=["weight", "payer_code", "medical_specialty"], inplace=False)

raw_data.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0       2278392      8222157        Caucasian  Female   [0-10)
# 1        149190     55629189        Caucasian  Female  [10-20)
# 2         64410     86047875  AfricanAmerican  Female  [20-30)
# 3        500364     82442376        Caucasian    Male  [30-40)
# 4         16680     42519267        Caucasian    Male  [40-50)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  num_lab_procedures  ...  citoglipton  insulin  \
# 0                 1                  41  ...           No       No
# ...

# %% [markdown]
# ### Drop rows that exceed the 20% acceptable threshold for missing values.

# %%
threshold = raw_data.shape[1] * 0.2

rows_to_drop = raw_data[raw_data.isnull().sum(axis=1) > threshold].shape[0]
rows_to_keep = raw_data.shape[0] - rows_to_drop

print(f"Total rows: {raw_data.shape[0]}")
print(f"Rows to drop (>20% missing): {rows_to_drop}")
print(f"Rows to keep: {rows_to_keep}")
# Out:
# Total rows: 101766
# Rows to drop (>20% missing): 0
# Rows to keep: 101766

# %% [markdown]
# Since no rows have more than 20% missing we don't do anything

# %% [markdown]
# ### Drop drug columns that are near constant (>= 99%).

# %%
DRUG_COLS = [
    "metformin","repaglinide","nateglinide","chlorpropamide","glimepiride",
    "acetohexamide","glipizide","glyburide","tolbutamide","pioglitazone",
    "rosiglitazone","acarbose","miglitol","troglitazone","tolazamide",
    "examide","citoglipton","insulin","glyburide-metformin","glipizide-metformin",
    "glimepiride-pioglitazone","metformin-rosiglitazone","metformin-pioglitazone"
]

drug_summary = raw_data[DRUG_COLS].apply(pd.Series.value_counts).T.fillna(0).astype(int)
drug_percentages = drug_summary.div(drug_summary.sum(axis=1), axis=0) * 100
  
drug_percentages
# Out:
#                                Down          No     Steady         Up
# metformin                  0.565022   80.358862  18.027632   1.048484
# repaglinide                0.044219   98.487707   1.359983   0.108091
# nateglinide                0.010809   99.309200   0.656408   0.023584
# chlorpropamide             0.000983   99.915492   0.077629   0.005896
# glimepiride                0.190633   94.899082   4.588959   0.321325
# acetohexamide              0.000000   99.999017   0.000983   0.000000
# glipizide                  0.550282   87.534147  11.158933   0.756638
# glyburide                  0.554213   89.534815   9.113063   0.797909
# tolbutamide                0.000000   99.977399   0.022601   0.000000
# pioglitazone               0.115952   92.799167   6.854942   0.229939
# rosiglitazone              0.085490   93.745455   5.994143   0.174911
# acarbose                   0.002948   99.697345   0.289881   0.009826
# ...

# %%
drop_drugs = [
    "nateglinide",
    "chlorpropamide",
    "acetohexamide",
    "tolbutamide",
    "acarbose",
    "miglitol",
    "troglitazone",
    "tolazamide",
    "examide",
    "citoglipton",
    "glyburide-metformin",
    "glipizide-metformin",
    "glimepiride-pioglitazone",
    "metformin-rosiglitazone",
    "metformin-pioglitazone"
]

raw_data = raw_data.drop(columns=drop_drugs, inplace=False)
raw_data.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0       2278392      8222157        Caucasian  Female   [0-10)
# 1        149190     55629189        Caucasian  Female  [10-20)
# 2         64410     86047875  AfricanAmerican  Female  [20-30)
# 3        500364     82442376        Caucasian    Male  [30-40)
# 4         16680     42519267        Caucasian    Male  [40-50)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  num_lab_procedures  ...  repaglinide  glimepiride  \
# 0                 1                  41  ...           No           No
# ...

# %% [markdown]
# ### Drop outliers

# %%
numeric_cols = [
    'time_in_hospital',
    'num_lab_procedures',
    'num_procedures',
    'num_medications',
    'number_outpatient',
    'number_emergency',
    'number_inpatient',
    'number_diagnoses'
]

p = 0.01
lower = raw_data[numeric_cols].quantile(p)
upper = raw_data[numeric_cols].quantile(1 - p)

mask = ((raw_data[numeric_cols] < lower) | (raw_data[numeric_cols] > upper)).any(axis=1)

raw_data = raw_data.loc[~mask].copy()

print(f"Remaining rows after drop: {len(raw_data)}")
# Out:
# Remaining rows after drop: 96573

# %% [markdown]
# ### Handle identifiers

# %%
patient_nbr_is_unique = raw_data["patient_nbr"].is_unique

encounter_id_is_unique = raw_data["encounter_id"].is_unique

print(f"Patient number is unique: {patient_nbr_is_unique}")
print(f"Encounter id is unique: {encounter_id_is_unique}")
# Out:
# Patient number is unique: False
# Encounter id is unique: True

# %%
dup_ids = raw_data["patient_nbr"][raw_data["patient_nbr"].duplicated()].unique()

duplicate_rows = raw_data[raw_data["patient_nbr"].isin(dup_ids)].sort_values(["patient_nbr"])

duplicate_rows.head(50)
# Out:
#        encounter_id  patient_nbr             race  gender      age  \
# 4267       24437208          135        Caucasian  Female  [50-60)
# 4780       26264286          135        Caucasian  Female  [50-60)
# 14180      55533660         1152  AfricanAmerican  Female  [60-70)
# 24642      83281464         1152  AfricanAmerican  Female  [60-70)
# 5953       30180318         1152  AfricanAmerican  Female  [50-60)
# 23623      80742510         1152  AfricanAmerican  Female  [60-70)
# 1164        8380170         1152  AfricanAmerican  Female  [50-60)
# 19914      70601076         1314        Caucasian  Female  [40-50)
# 19765      70190028         1314        Caucasian  Female  [40-50)
# 15848      60254142         1314        Caucasian  Female  [40-50)
# 16105      60892254         5220        Caucasian    Male  [70-80)
# 14128      55397514         5220        Caucasian    Male  [70-80)
# 6901       33503946         5220        Caucasian    Male  [70-80)
# ...

# %% [markdown]
# Both the patient number and encounter ID are identifiers. While the patient number may not be unique, the dataset is based on individual encounters, so these features won't contribute to model training and will be dropped.

# %%
raw_data = raw_data.drop(columns=["encounter_id"], inplace=False)

raw_data.head()
# Out:
#    patient_nbr             race  gender      age  admission_type_id  \
# 1     55629189        Caucasian  Female  [10-20)                  1
# 2     86047875  AfricanAmerican  Female  [20-30)                  1
# 3     82442376        Caucasian    Male  [30-40)                  1
# 4     42519267        Caucasian    Male  [40-50)                  1
# 5     82637451        Caucasian    Male  [50-60)                  2
#
#    discharge_disposition_id  admission_source_id  time_in_hospital  \
# 1                         1                    7                 3
# 2                         1                    7                 2
# 3                         1                    7                 2
# 4                         1                    7                 1
# 5                         1                    2                 3
#
#    num_lab_procedures  num_procedures  ...  repaglinide  glimepiride  \
# 1                  59               0  ...           No           No
# ...

# %% [markdown]
# ### Apply One-Hot Encoding to specific columns

# %%
OHE_COLS = [
    "race",
    "gender",
    "max_glu_serum",
    "A1Cresult"
]

raw_data = pd.get_dummies(raw_data, columns=OHE_COLS, drop_first=False, dtype=int)

raw_data.head()
# Out:
#    patient_nbr      age  admission_type_id  discharge_disposition_id  \
# 1     55629189  [10-20)                  1                         1
# 2     86047875  [20-30)                  1                         1
# 3     82442376  [30-40)                  1                         1
# 4     42519267  [40-50)                  1                         1
# 5     82637451  [50-60)                  2                         1
#
#    admission_source_id  time_in_hospital  num_lab_procedures  num_procedures  \
# 1                    7                 3                  59               0
# 2                    7                 2                  11               5
# 3                    7                 2                  44               1
# 4                    7                 1                  51               0
# 5                    2                 3                  31               6
#
#    num_medications  number_outpatient  ...  gender_Male  \
# ...

# %% [markdown]
# ### Apply Ordinal Encoding to specific columns

# %%
ordinal_cols = [
    "admission_type_id",
    "discharge_disposition_id",
    "admission_source_id",
]

for col in ordinal_cols:
    raw_data[col] = pd.factorize(raw_data[col])[0]

raw_data[ordinal_cols].head()
# Out:
#    admission_type_id  discharge_disposition_id  admission_source_id
# 1                  0                         0                    0
# 2                  0                         0                    0
# 3                  0                         0                    0
# 4                  0                         0                    0
# 5                  1                         0                    1

# %% [markdown]
# ### Apply Ordinal Encoding to `age`

# %%
age_map = {
    "[0-10)":0, "[10-20)":1, "[20-30)":2, "[30-40)":3,
    "[40-50)":4, "[50-60)":5, "[60-70)":6, "[70-80)":7,
    "[80-90)":8, "[90-100)":9
}

raw_data["age"] = raw_data["age"].map(age_map).astype(int)
raw_data.head()
# Out:
#    patient_nbr  age  admission_type_id  discharge_disposition_id  \
# 1     55629189    1                  0                         0
# 2     86047875    2                  0                         0
# 3     82442376    3                  0                         0
# 4     42519267    4                  0                         0
# 5     82637451    5                  1                         0
#
#    admission_source_id  time_in_hospital  num_lab_procedures  num_procedures  \
# 1                    0                 3                  59               0
# 2                    0                 2                  11               5
# 3                    0                 2                  44               1
# 4                    0                 1                  51               0
# 5                    1                 3                  31               6
#
#    num_medications  number_outpatient  ...  gender_Male  \
# ...

# %% [markdown]
# ### Apply Ordinal Encoding to drug columns

# %%
DRUG_COLS = [
    "metformin","repaglinide","glimepiride","glipizide","glyburide","pioglitazone","rosiglitazone","insulin"
]

for col in DRUG_COLS:
    unique_values_drugs = raw_data[col].unique()
    print(f"{col}: {unique_values_drugs}")
# Out:
# metformin: ['No' 'Steady' 'Up' 'Down']
# repaglinide: ['No' 'Up' 'Steady' 'Down']
# glimepiride: ['No' 'Steady' 'Down' 'Up']
# glipizide: ['No' 'Steady' 'Up' 'Down']
# glyburide: ['No' 'Steady' 'Up' 'Down']
# pioglitazone: ['No' 'Steady' 'Up' 'Down']
# rosiglitazone: ['No' 'Steady' 'Up' 'Down']
# insulin: ['Up' 'No' 'Steady' 'Down']

# %%
drug_map = {"No":0, "Down":1, "Steady":2, "Up":3}

for col in DRUG_COLS:
    raw_data[col] = raw_data[col].map(drug_map).astype(int)

raw_data.head()
# Out:
#    patient_nbr  age  admission_type_id  discharge_disposition_id  \
# 1     55629189    1                  0                         0
# 2     86047875    2                  0                         0
# 3     82442376    3                  0                         0
# 4     42519267    4                  0                         0
# 5     82637451    5                  1                         0
#
#    admission_source_id  time_in_hospital  num_lab_procedures  num_procedures  \
# 1                    0                 3                  59               0
# 2                    0                 2                  11               5
# 3                    0                 2                  44               1
# 4                    0                 1                  51               0
# 5                    1                 3                  31               6
#
#    num_medications  number_outpatient  ...  gender_Male  \
# ...

# %% [markdown]
# ### Apply Binary Encoding to `change` and `diabetesMed`

# %%
unique_values_change = raw_data["change"].unique()
print(f"Change: {unique_values_change}")
# Out:
# Change: ['Ch' 'No']

# %%
unique_values_diabetesMed = raw_data["diabetesMed"].unique()
print(f"DiabetesMed: {unique_values_diabetesMed}")
# Out:
# DiabetesMed: ['Yes' 'No']

# %%
binary_map = {"No":0, "Ch":1, "Yes":1}
raw_data["change"] = raw_data["change"].map(binary_map).astype(int)
raw_data["diabetesMed"] = raw_data["diabetesMed"].map(binary_map).astype(int)

raw_data.head()
# Out:
#    patient_nbr  age  admission_type_id  discharge_disposition_id  \
# 1     55629189    1                  0                         0
# 2     86047875    2                  0                         0
# 3     82442376    3                  0                         0
# 4     42519267    4                  0                         0
# 5     82637451    5                  1                         0
#
#    admission_source_id  time_in_hospital  num_lab_procedures  num_procedures  \
# 1                    0                 3                  59               0
# 2                    0                 2                  11               5
# 3                    0                 2                  44               1
# 4                    0                 1                  51               0
# 5                    1                 3                  31               6
#
#    num_medications  number_outpatient  ...  gender_Male  \
# ...

# %% [markdown]
# ### Apply Ordinal Encoding to `readmitted` which is our target variable

# %%
unique_values_change = raw_data["readmitted"].unique()
print(f"Readmitted: {unique_values_change}")
# Out:
# Readmitted: ['>30' 'NO' '<30']

# %%
readmitted_binary_map = {"NO":0, ">30":0, "<30":1}
raw_data["readmitted"] = raw_data["readmitted"].map(readmitted_binary_map).astype(int)

raw_data.head()
# Out:
#    patient_nbr  age  admission_type_id  discharge_disposition_id  \
# 1     55629189    1                  0                         0
# 2     86047875    2                  0                         0
# 3     82442376    3                  0                         0
# 4     42519267    4                  0                         0
# 5     82637451    5                  1                         0
#
#    admission_source_id  time_in_hospital  num_lab_procedures  num_procedures  \
# 1                    0                 3                  59               0
# 2                    0                 2                  11               5
# 3                    0                 2                  44               1
# 4                    0                 1                  51               0
# 5                    1                 3                  31               6
#
#    num_medications  number_outpatient  ...  gender_Male  \
# ...

# %% [markdown]
# # Map `diag_1` to ICD9

# %%
unique_values_diag1 = raw_data["diag_1"].unique()
print(f"Diagnosis 1: {unique_values_diag1}")
# Out:
# Diagnosis 1: ['276' '648' '8' '197' '414' '428' '398' '434' '250.7' '157' '999' '410'
#  '682' '402' '737' '572' 'V57' '189' '786' '427' '996' '277' '462' '473'
#  '411' '174' '486' '998' '511' '432' '626' '295' '196' '250.6' '618' '182'
#  '845' '423' '808' '250.4' '722' '403' '784' '707' '440' '151' '715' '997'
#  '198' '564' '812' '38' '590' '556' '578' '433' 'V58' '569' '185' '536'
#  '250.32' '255' '250.13' '599' '558' '574' '491' '584' '560' '244'
#  '250.03' '577' '730' '188' '824' '250.8' '332' '562' '291' '296' '510'
#  '401' '263' '438' '70' '250.02' '493' '642' '625' '571' '738' '593'
#  '250.42' '807' '456' '446' '518' '575' '250.41' '820' '515' '780'
#  '250.22' '995' '235' '250.82' '721' '787' '162' '724' '282' '250.83'
#  'V55' '281' '250.33' '530' '435' '250.12' 'V53' '789' '566' '822'
#  '250.11' '191' '557' '733' '455' '711' '482' '202' '280' '553' '225'
#  '154' '441' '250.81' '349' nan '962' '592' '507' '386' '156' '200' '728'
# ...

# %%
raw_data = raw_data.drop(columns=["diag_2", "diag_3"], inplace=False)

# %% [markdown]
# Dropping diag2 and diag3 to focus on diag1, which is the first diagnoses. This is to reduce noise in our model.

# %% [markdown]
# ### Drop empty `diag_1` columns
#
# In this case we will not do imputation because of the bias that can be introduced and since the number of empty columns aren't a lot.

# %%
empty_diag1 = raw_data["diag_1"].isna().sum()

print(f"Empty in diag1: {empty_diag1}")
# Out:
# Empty in diag1: 21

# %%
raw_data = raw_data.dropna(subset=["diag_1"])

# %%
# Sanity check
print("Empty in diag1:", raw_data["diag_1"].isna().sum())
# Out:
# Empty in diag1: 0

# %%
chapters = pd.read_csv("../data/external/icd9_chapters.csv")

# %%
def safe_int(x):
    if pd.isna(x):
        return None
    s = str(x).strip().upper().replace("V", "").replace("E", "").replace(".", "")
    try:
        return int(s)
    except ValueError:
        return None

def bucket_icd9(code: str) -> str:
    if pd.isna(code):
        return "Unknown"

    s = str(code).strip().upper()

    # V / E chapters
    if s.startswith("V"):
        return "Supplementary Factors (V)"
    if s.startswith("E"):
        return "External Causes (E)"

    s_digits = re.sub(r"\.", "", s)
    m = re.match(r"^(\d{3})", s_digits)
    if not m:
        return "Unknown"

    three = int(m.group(1))

    # Look up in chapter ranges
    for _, row in chapters.iterrows():
        if row["start_num"] is not None and row["end_num"] is not None:
            if row["start_num"] <= three <= row["end_num"]:
                return row["name"]

    return "Other/Unmapped"

chapters["start_num"] = chapters["start"].apply(safe_int)
chapters["end_num"]   = chapters["end"].apply(safe_int)

c = "diag_1"

raw_data[c + "_grp"] = raw_data[c].apply(bucket_icd9)

# %%
raw_data.head()
# Out:
#    patient_nbr  age  admission_type_id  discharge_disposition_id  \
# 1     55629189    1                  0                         0
# 2     86047875    2                  0                         0
# 3     82442376    3                  0                         0
# 4     42519267    4                  0                         0
# 5     82637451    5                  1                         0
#
#    admission_source_id  time_in_hospital  num_lab_procedures  num_procedures  \
# 1                    0                 3                  59               0
# 2                    0                 2                  11               5
# 3                    0                 2                  44               1
# 4                    0                 1                  51               0
# 5                    1                 3                  31               6
#
#    num_medications  number_outpatient  ...  gender_Unknown/Invalid  \
# ...

# %%
raw_data = raw_data.drop(columns=["diag_1"], inplace=False)

# %% [markdown]
# ### Apply One-Hot Encoding to diag1_grp

# %%
raw_data = pd.get_dummies(
    raw_data,
    columns=["diag_1_grp"],
    prefix="diag1",
    drop_first=False,
    dtype=int
)

raw_data.head()
# Out:
#    patient_nbr  age  admission_type_id  discharge_disposition_id  \
# 1     55629189    1                  0                         0
# 2     86047875    2                  0                         0
# 3     82442376    3                  0                         0
# 4     42519267    4                  0                         0
# 5     82637451    5                  1                         0
#
#    admission_source_id  time_in_hospital  num_lab_procedures  num_procedures  \
# 1                    0                 3                  59               0
# 2                    0                 2                  11               5
# 3                    0                 2                  44               1
# 4                    0                 1                  51               0
# 5                    1                 3                  31               6
#
#    num_medications  number_outpatient  ...  diag1_Mental/Behavioral  \
# ...

# %% [markdown]
# # SANITY CHECKS

# %% [markdown]
# ### Check if there are any non-numeric columns left

# %%
# Sanity check
non_numeric = raw_data.select_dtypes(exclude=["number"]).columns
print("Non-numeric columns:", non_numeric.tolist())
# Out:
# Non-numeric columns: []

# %% [markdown]
# ### Check if there are any missing value columns left

# %%
is_null = raw_data.isna().sum()
print(is_null[is_null > 0])
# Out:
# Series([], dtype: int64)

# %%
unknown_cols = [col for col in raw_data.columns if "unknown" in col.lower()]

unknown_counts = raw_data[unknown_cols].sum()

print(unknown_counts)
# Out:
# gender_Unknown/Invalid       3
# diag1_Unknown             2495
# dtype: int64

# %% [markdown]
# ### Drop the trivial 3 rows with gender as unknown/invalid

# %%
raw_data = raw_data[raw_data["gender_Unknown/Invalid"] == 0]

raw_data = raw_data.drop(columns=["gender_Unknown/Invalid"])

# %%
raw_data.to_csv("../data/processed/processed.csv", index=False)
